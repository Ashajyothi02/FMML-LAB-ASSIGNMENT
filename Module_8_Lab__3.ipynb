# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashajyothi02/FMML-LAB-ASSIGNMENT/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 05:22:02--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   220MB/s    in 0.3s
#
# 2024-03-28 05:22:04 (220 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6281   1610.08838v1  Supervised dimensionality reduction has emerge...  stat
# 22585  1702.01000v2  Forward regression is a statistical model sele...  stat
# 21503   0709.2989v1  Simulated annealing is a popular method for ap...  stat
# 23471   1209.4317v1  Image super-resolution (SR) is one of the long...    cs
# 32449   1003.2218v1  We apply the method of defensive forecasting, ...    cs
# ...             ...                                                ...   ...
# 22379  1605.02541v2  We study in this paper the consequences of usi...  stat
# 28950  1708.01034v1  In computer vision, video-based approaches hav...    cs
# 15216  1612.04629v3  Analysing translation quality in regards to sp...    cs
# 14729   1111.0048v1  One of the biggest challenges in the developme...    cs
# 6606   1704.00767v1  The Support Vector Machine (SVM) is a powerful...  stat
#
#                                                    title  year  \
# 6281   A Category Space Approach to Supervised Dimens...  2016
# 22585  Sharp Convergence Rates for Forward Regression...  2017
# 21503  Simulated Annealing: Rigorous finite-time guar...  2007
# 23471  Image Super-Resolution via Sparse Bayesian Mod...  2012
# 32449  Supermartingales in Prediction with Expert Advice  2010
# ...                                                  ...   ...
# 22379  Mean Absolute Percentage Error for regression ...  2016
# 28950  What Will I Do Next? The Intention from Motion...  2017
# 15216  How Grammatical is Character-level Neural Mach...  2016
# 14729  Individual and Domain Adaptation in Sentence P...  2011
# 6606   Geometric Insights into Support Vector Machine...  2017
#
#                                                 keywords
# 6281   [supervised, dimensionality, reduction, import...
# 22585  [regression, statistical, selection, estimatio...
# 21503  [simulated, annealing, approaching, optimizati...
# 23471  [resolution, processing, community, resolution...
# 32449  [defensive, forecasting, theoretic, supermarti...
# ...                                                  ...
# 22379  [consequences, percentage, regression, existen...
# 28950  [approaches, classification, prediction, activ...
# 15216  [analysing, translation, linguistic, phenomena...
# 14729  [challenges, development, deployment, generati...
# 6606   [classification, algorithm, performance, param...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6281     [supervised, dimensionality, reduction, import...
# 22585    [regression, statistical, selection, estimatio...
# 21503    [simulated, annealing, approaching, optimizati...
# 23471    [resolution, processing, community, resolution...
# 32449    [defensive, forecasting, theoretic, supermarti...
#                                ...
# 30903    [associated, traditionally, formulated, mathem...
# 12433    [amplitude, envelopes, convincing, synthesis, ...
# 34689    [techniques, relational, documents, questions,...
# 34586    [summarization, scientific, advantage, discour...
# 13523    [generation, artificial, information, differen...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8789 words.
# Out of those 4569 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e958cada-8cf9-4cba-8e5f-db8fd4133bfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e958cada-8cf9-4cba-8e5f-db8fd4133bfc")) {                    Plotly.newPlot(                        "e958cada-8cf9-4cba-8e5f-db8fd4133bfc",                        [{"x":["automatically","reduction","quadratic","nevertheless","component","orthogonality","formulated","important","formulating","formulation","imposition","comparisons","structure","represented","projected","formulations","cardinality","supervised","minimization","optimization","dimensionality","resulting","reproducing","functions","principal","discrimination","straightforward","guaranteed","parameters","estimated","conditions","procedure","selection","covariates","inductively","estimation","predictive","probabilistic","prediction","dimensional","convergence","statistical","regression","connection","confidence","continuous","variables","simulated","developed","annealing","universally","performance","establish","approaching","guarantee","combinatorial","guarantees","introduce","regularized","factorial","competitive","regularization","algorithm","incorporates","sacrifices","algorithms","separable","potential","posterior","processing","community","introducing","correlations","substantially","experimental","techniques","empirical","adaptation","resolution","coefficients","posteriori","formulate","exploited","different","application","countable","aggregating","defensive","conditional","traditional","forecasting","theoretic","predictions","fundamentally","experiments","significant","comparable","applications","logitboost","establishing","naturally","substantial","demonstrated","constructions","competitors","exponentiated","linearized","including","generalized","modifying","excellent","efficiently","extensively","improvements","typically","classification","derivatives","available","accommodate","extension","arbitrary","framework","candidate","discovery","sensitivity","estimates","applicable","simultaneously","nonparametric","efficient","demonstrate","threshold","distributions","compounds","sensitive","principled","thousands","identifying","correlation","activities","identification","essential","specificity","providing","screening","implemented","individual","involving","throughput","difficult","navigation","remaining","simplicity","analysing","scalability","compromise","interaction","successful","visualizing","conceptually","hierarchies","cumbersome","possibilities","expressivity","conceptual","interpretation","usability","drawbacks","bottleneck","interacting","experimented","visualization","theoretically","facilitated","attribute","minimises","outperforms","maximising","retrieval","canonical","projections","representation","interested","presented","explained","alternative","heuristic","direction","systematically","technique","heuristics","prohibitively","improving","efficiency","exploring","fundamental","expensive","developing","hypothesis","significance"],"y":[179,107,26,19,98,1,37,371,7,74,1,39,342,82,19,16,10,163,57,317,45,146,8,245,34,19,21,26,247,62,158,107,163,0,2,188,56,136,236,195,117,177,122,39,47,111,144,49,219,9,1,897,41,7,38,45,59,346,46,6,115,83,795,25,2,563,14,148,41,295,79,54,31,27,391,376,139,57,124,25,15,62,29,735,232,3,12,5,85,166,18,42,107,12,593,248,101,427,1,16,58,48,103,3,5,1,5,251,70,15,25,150,28,121,106,513,9,296,5,74,89,536,46,59,43,66,49,109,15,411,539,32,98,6,59,20,34,69,79,28,108,67,9,88,10,102,124,56,12,145,32,27,14,13,32,7,67,74,14,7,11,9,15,3,18,59,9,12,25,19,7,32,36,1,41,0,260,2,101,19,18,373,26,180,17,85,48,58,10,230,32,7,94,174,30,72,56,57,53,14],"type":"bar"},{"x":["automatically","reduction","quadratic","nevertheless","component","orthogonality ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4569,), (4569, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Comment</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>by</span> <span style=''>fast</span> <span style=''>search</span> <span style=''>and</span> <span style=''>find</span> <span style=''>of</span> <span style=''>density</span> <span style=''>peaks</span> <br/><br/><span style=''>In</span> <span style=''>1</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>was</span> <span style=''>given</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style=''>centers</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>quickly</span> <span style=''>However</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>heavily</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>threshold</span> <span style=''>value</span> <span style=''>of</span> <span style=''>d</span> <span style=''>c</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>1</span> <span style=''>has</span> <span style=''>not</span> <span style=''>provided</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>way</span> <span style=''>to</span> <span style=''>select</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>threshold</span> <span style=''>value</span> <span style=''>of</span> <span style=''>d</span> <span style=''>c</span> <span style=''>that</span> <span style=''>is</span> <span style=''>one</span> <span style=''>can</span> <span style=''>have</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>value</span> <span style=''>of</span> <span style=''>d</span> <span style=''>c</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>ones</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333333);'>subjective</span> <span style='background-color:rgba(0, 255, 0, 0.320754716981132);'>experience</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>data</span> <span style=''>field</span> <span style=''>2</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>way</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3929961089494164);'>automatically</span> <span style=''>extract</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>threshold</span> <span style=''>value</span> <span style=''>of</span> <span style=''>d</span> <span style=''>c</span> <span style=''>from</span> <span style=''>the</span> <span style=''>original</span> <span style=''>data</span> <span style=''>set</span> <span style=''>by</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>entropy</span> <span style=''>of</span> <span style=''>data</span> <span style=''>field</span> <span style=''>For</span> <span style=''>any</span> <span style=''>data</span> <span style=''>set</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustered</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reasonable</span> <span style=''>value</span> <span style=''>of</span> <span style=''>d</span> <span style=''>c</span> <span style=''>can</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Black</span> <span style=''>box</span> <span style=''>α</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Minimization</span> <br/><br/><span style=''>Black</span> <span style=''>box</span> <span style=''>alpha</span> <span style=''>(BB</span> <span style=''>alpha)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>alpha</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergences</span> <span style=''>BB</span> <span style=''>alpha</span> <span style=''>scales</span> <span style=''>to</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>because</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>BB</span> <span style=''>alpha</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>with</span> <span style=''>little</span> <span style=''>effort</span> <span style=''>since</span> <span style=''>it</span> <span style=''>only</span> <span style=''>requires</span> <span style=''>as</span> <span style=''>input</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>function</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>obtained</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differentiation</span> <span style=''>By</span> <span style=''>changing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>alpha</span> <span style=''>the</span> <span style=''>method</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpolate</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>Bayes</span> <span style=''>(VB)</span> <span style=''>(alpha</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rightarrow</span> <span style=''>0)</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>similar</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style=''>(EP)</span> <span style=''>(alpha</span> <span style=''>1)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style=''>probit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style=''>neural</span> <span style=''>network</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3468354430379746);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conjugate</span> <span style=''>Gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>with</span> <span style=''>Variance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reduction</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Conjugate</span> <span style=''>gradient</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equations</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>In</span> <span style=''>our</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3468354430379746);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjugate</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>variance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style=''>(CGVR)</span> <span style=''>and</span> <span style=''>prove</span> <span style=''>its</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3035714285714286);'>convergence</span> <span style=''>with</span> <span style=''>the</span> <span style=''>Fletcher</span> <span style=''>and</span> <span style=''>Revves</span> <span style=''>method</span> <span style=''>for</span> <span style=''>strongly</span> <span style=''>convex</span> <span style=''>and</span> <span style=''>smooth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experimentally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>the</span> <span style=''>CGVR</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.30555555555555547);'>converges</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>counterparts</span> <span style=''>for</span> <span style=''>six</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>that</span> <span style=''>may</span> <span style=''>be</span> <span style=''>convex</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>or</span> <span style=''>non</span> <span style=''>smooth</span> <span style=''>and</span> <span style=''>its</span> <span style=''>AUC</span> <span style=''>(Area</span> <span style=''>Under</span> <span style=''>Curve)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>with</span> <span style=''>L2</span> <span style='background-color:rgba(255, 0, 0, 0.3947368421052631);'>regularized</span> <span style=''>L2</span> <span style=''>loss</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparable</span> <span style=''>to</span> <span style=''>that</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>LIBLINEAR</span> <span style=''>but</span> <span style=''>with</span> <span style='background-color:rgba(0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Understanding</span> <span style=''>the</span> <span style=''>Energy</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Precision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Requirements</span> <span style=''>for</span> <span style=''>Online</span> <span style=''>Learning</span> <br/><br/><span style=''>It</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>of</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>and</span> <span style=''>internal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>employed</span> <span style=''>in</span> <span style=''>learning</span> <span style=''>systems</span> <span style=''>directly</span> <span style=''>impacts</span> <span style=''>its</span> <span style=''>energy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>throughput</span> <span style=''>and</span> <span style=''>latency</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirements</span> <span style=''>for</span> <span style=''>the</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>are</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>for</span> <span style=''>systems</span> <span style=''>that</span> <span style=''>learn</span> <span style=''>on</span> <span style=''>the</span> <span style=''>fly</span> <span style=''>Prior</span> <span style=''>work</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>the</span> <span style=''>data</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantized</span> <span style=''>heavily</span> <span style=''>without</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incurring</span> <span style=''>much</span> <span style=''>penalty</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>accuracy</span> <span style=''>when</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>floating</span> <span style=''>point</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementations</span> <span style=''>These</span> <span style=''>works</span> <span style=''>suffer</span> <span style=''>from</span> <span style=''>two</span> <span style=''>key</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitations</span> <span style=''>First</span> <span style=''>they</span> <span style=''>assume</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>and</span> <span style=''>for</span> <span style=''>the</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>miss</span> <span style=''>out</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>opportunity</span> <span style=''>to</span> <span style=''>further</span> <span style=''>reduce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>Second</span> <span style=''>prior</span> <span style='' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1333095067905647)
# 	processing (0.10543245175125089)
# 	segmentation (0.07219442458899214)
# 	experimental (0.13974267333809864)
# 	architecture (0.09185132237312366)
# 	different (0.26268763402430306)
# 	information (0.2505360972122945)
# 	detection (0.12937812723373837)
# 	convolutional (0.13473909935668335)
# 	recognition (0.13974267333809864)
#
# Some Statistics words are:
# 	stochastic (0.13286713286713286)
# 	variables (0.13936063936063936)
# 	theoretical (0.14635364635364637)
# 	statistical (0.15934065934065933)
# 	algorithm (0.38311688311688313)
# 	estimation (0.17632367632367632)
# 	dimensional (0.18831168831168832)
# 	distribution (0.1943056943056943)
# 	inference (0.2042957042957043)
# 	regression (0.17782217782217782)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="53be0900-e3d3-443a-ac4d-00aa4233d3d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53be0900-e3d3-443a-ac4d-00aa4233d3d0")) {                    Plotly.newPlot(                        "53be0900-e3d3-443a-ac4d-00aa4233d3d0",                        [{"x":["automatically","reduction","quadratic","nevertheless","component","orthogonality","formulated","important","formulating","formulation","imposition","comparisons","structure","represented","projected","formulations","cardinality","supervised","minimization","optimization","dimensionality","resulting","reproducing","functions","principal","discrimination","straightforward","guaranteed","parameters","estimated","conditions","procedure","selection","covariates","inductively","estimation","predictive","probabilistic","prediction","dimensional","convergence","statistical","regression","connection","confidence","continuous","variables","simulated","developed","annealing","universally","performance","establish","approaching","guarantee","combinatorial","guarantees","introduce","regularized","factorial","competitive","regularization","algorithm","incorporates","sacrifices","algorithms","separable","potential","posterior","processing","community","introducing","correlations","substantially","experimental","techniques","empirical","adaptation","resolution","coefficients","posteriori","formulate","exploited","different","application","countable","aggregating","defensive","conditional","traditional","forecasting","theoretic","predictions","fundamentally","experiments","significant","comparable","applications","logitboost","establishing","naturally","substantial","demonstrated","constructions","competitors","exponentiated","linearized","including","generalized","modifying","excellent","efficiently","extensively","improvements","typically","classification","derivatives","available","accommodate","extension","arbitrary","framework","candidate","discovery","sensitivity","estimates","applicable","simultaneously","nonparametric","efficient","demonstrate","threshold","distributions","compounds","sensitive","principled","thousands","identifying","correlation","activities","identification","essential","specificity","providing","screening","implemented","individual","involving","throughput","difficult","navigation","remaining","simplicity","analysing","scalability","compromise","interaction","successful","visualizing","conceptually","hierarchies","cumbersome","possibilities","expressivity","conceptual","interpretation","usability","drawbacks","bottleneck","interacting","experimented","visualization","theoretically","facilitated","attribute","minimises","outperforms","maximising","retrieval","canonical","projections","representation","interested","presented","explained","alternative","heuristic","direction","systematically","technique","heuristics","prohibitively","improving","efficiency","exploring","fundamental","expensive","developing","hypothesis","significance","independence","graphical","intelligence","relationship","calculation","multinomial","attention","literature","especially","computational","indicator","likelihood","unexpected","describes","encountering","responses","environments","information","dynamically","phenomena","environment","balancing","eventually","minimizing","behavioral","exploration","surprising","statistics","commitment","distribution","undergoes","knowledge","assumptions","incorporated","assumption","optimality","exploitation","effective","multivariate","underlying","attractive","therefore","ambiguities","additional","description","properties","development","accurately","motivates","mathematical","applicability","dependencies","estimator","theoretical","improveme ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	covariates
# 	minimises
# 	varepsilon
# 	uninformative
# 	repulsive
# 	magnetoencephalographic
# 	regressions
# 	rewritten
# 	practiced
# 	celebrated
# 	questionnaires
# 	subsamples
# 	obtainable
# 	emphmulti
# 	judiciously
# 	combinatorially
# 	underpowered
# 	uncontaminated
# 	modulating
# 	sparsistent
# Some words which never appear in Statistics papers:
# 	sacrifices
# 	invisible
# 	imagination
# 	norwegian
# 	broadening
# 	metaheuristics
# 	customizable
# 	subjected
# 	inheritance
# 	benefiting
# 	recruitment
# 	occupancy
# 	reception
# 	avoidance
# 	satisfiability
# 	unsatisfiable
# 	photographs
# 	departures
# 	broadband
# 	homography

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.072291007404222e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7675
